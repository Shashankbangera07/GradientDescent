# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashankbangera07/GradientDescent/blob/main/Gradient_Descent_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1,n_informative=1, n_targets=1, noise = 20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [86.66497459]
# -2.0666594391920463

# %%
m = 86.66497459

# %%
class GDRegressor:

  def __init__(self,learning_rate, epochs):
    self.m = 86.66
    self.b = -120
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,X,y):
  #calculate the b using GD
    for i in range(self.epochs):
      loss_slope = -2 * np.sum(y - self.m * X.ravel() - self.b)
      self.b = self.b - (self.lr * loss_slope)
      print(loss_slope, self.b)
    print(self.b)

# %%
gd = GDRegressor(0.001, 100)

# %%
gd.fit(X,y)
# Out:
# -23586.638135455596 -96.4133618645444
# -18869.31050836447 -77.54405135617992
# -15095.448406691577 -62.44860294948835
# -12076.358725353262 -50.37224422413509
# -9661.086980282613 -40.711157243852476
# -7728.869584226089 -32.98228765962639
# -6183.095667380871 -26.799191992245515
# -4946.476533904696 -21.852715458340818
# -3957.1812271237573 -17.89553423121706
# -3165.7449816990056 -14.729789249518053
# -2532.5959853592044 -12.197193264158848
# -2026.0767882873633 -10.171116475871484
# -1620.8614306298905 -8.550255045241594
# -1296.6891445039128 -7.253565900737681
# -1037.35131560313 -6.216214585134551
# -829.881052482504 -5.386333532652047
# -663.9048419860031 -4.722428690666044
# -531.1238735888027 -4.191304817077242
# -424.8990988710422 -3.7664057182061996
# -339.91927909683375 -3.426486439109366
# -271.93542327746707 -3.154551015831899
# -217.54833862197358 -2.9370026772099256
# -174.03867089757887 -2.762964006312347
# -139.2309367180631 -2.6237330695942838
# ...
